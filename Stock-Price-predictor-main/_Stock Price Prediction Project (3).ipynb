# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load dataframe
df = pd.read_csv("C:/Users/NOOMAN KHAN/Downloads/stock_nifty50.csv")
df.head()
# Out:
#    Unnamed: 0        Date    Symbol Series  Prev Close   Open    High     Low  \
# 0           0  2018-12-12  ADANIENT     EQ      151.90  152.8  157.00  151.05
# 1           1  2018-12-13  ADANIENT     EQ      156.10  156.0  158.60  154.00
# 2           2  2018-12-14  ADANIENT     EQ      156.00  156.0  157.90  154.10
# 3           3  2018-12-17  ADANIENT     EQ      157.10  157.1  158.90  156.35
# 4           4  2018-12-18  ADANIENT     EQ      157.95  157.7  159.75  156.20
#
#      Last   Close    VWAP   Volume      Turnover  Trades  Deliverable Volume  \
# 0  156.00  156.10  154.50  4377945  6.763819e+13   25254              230979
# 1  154.15  156.00  156.58  3499313  5.479299e+13   20136              241770
# 2  157.00  157.10  155.90  3389589  5.284529e+13   19917              235044
# 3  158.00  157.95  157.60  1595605  2.514683e+13   11049              133437
# 4  158.10  158.05  158.14  1689582  2.671824e+13   10488              117265
#
#    %Deliverble
# 0       0.0528
# ...

# %%
# information about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47616 entries, 0 to 47615
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          47616 non-null  int64
#  1   Date                47616 non-null  object
#  2   Symbol              47616 non-null  object
#  3   Series              47616 non-null  object
#  4   Prev Close          47616 non-null  float64
#  5   Open                47616 non-null  float64
#  6   High                47616 non-null  float64
#  7   Low                 47616 non-null  float64
#  8   Last                47616 non-null  float64
#  9   Close               47616 non-null  float64
#  10  VWAP                47616 non-null  float64
#  11  Volume              47616 non-null  int64
#  12  Turnover            47616 non-null  float64
#  13  Trades              47616 non-null  int64
#  14  Deliverable Volume  47616 non-null  int64
# ...

# %%
df["Symbol"].unique()
# Out:
# array(['ADANIENT', 'ADANIPORTS', 'APOLLOHOSP', 'ASIANPAINT', 'AXISBANK',
#        'BAJAJ-AUTO', 'BAJFINANCE', 'BAJAJFINSV', 'BPCL', 'BHARTIARTL',
#        'BRITANNIA', 'CIPLA', 'COALINDIA', 'DIVISLAB', 'DRREDDY',
#        'EICHERMOT', 'GRASIM', 'HCLTECH', 'HDFCBANK', 'HINDALCO',
#        'HINDUNILVR', 'HDFC', 'ICICIBANK', 'ITC', 'INDUSINDBK', 'INFY',
#        'JSWSTEEL', 'KOTAKBANK', 'LT', 'M&M', 'MARUTI', 'NTPC',
#        'NESTLEIND', 'ONGC', 'POWERGRID', 'RELIANCE', 'SBILIFE', 'SBIN',
#        'SUNPHARMA', 'TCS', 'TATAGLOBAL', 'TATACONSUM', 'TATAMOTORS',
#        'TATASTEEL', 'TECHM', 'TITAN', 'UPL', 'ULTRACEMCO', 'WIPRO'],
#       dtype=object)

# %%
df["Symbol"].nunique()
# Out:
# 49

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Date                  0
# Symbol                0
# Series                0
# Prev Close            0
# Open                  0
# High                  0
# Low                   0
# Last                  0
# Close                 0
# VWAP                  0
# Volume                0
# Turnover              0
# Trades                0
# Deliverable Volume    0
# %Deliverble           0
# dtype: int64

# %%
df = df.drop("Unnamed: 0" , axis = 1)

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
df.dtypes
# Out:
# Date                  datetime64[ns]
# Symbol                        object
# Series                        object
# Prev Close                   float64
# Open                         float64
# High                         float64
# Low                          float64
# Last                         float64
# Close                        float64
# VWAP                         float64
# Volume                         int64
# Turnover                     float64
# Trades                         int64
# Deliverable Volume             int64
# %Deliverble                  float64
# dtype: object

# %%
from datetime import datetime

# %%
df1 = df.copy()

# %%
df1["Year"] = df1["Date"].dt.year

# %%
df1["Month"] = df1["Date"].dt.month

# %%
df1["Day"] = df1["Date"].dt.day

# %%
df1 = df1.drop(["Volume","Turnover","Trades","Deliverable Volume","%Deliverble"] , axis = 1)

# %%
df1["Symbol"].nunique()
# Out:
# 49

# %%
df1["Symbol"].unique()
# Out:
# array(['ADANIENT', 'ADANIPORTS', 'APOLLOHOSP', 'ASIANPAINT', 'AXISBANK',
#        'BAJAJ-AUTO', 'BAJFINANCE', 'BAJAJFINSV', 'BPCL', 'BHARTIARTL',
#        'BRITANNIA', 'CIPLA', 'COALINDIA', 'DIVISLAB', 'DRREDDY',
#        'EICHERMOT', 'GRASIM', 'HCLTECH', 'HDFCBANK', 'HINDALCO',
#        'HINDUNILVR', 'HDFC', 'ICICIBANK', 'ITC', 'INDUSINDBK', 'INFY',
#        'JSWSTEEL', 'KOTAKBANK', 'LT', 'M&M', 'MARUTI', 'NTPC',
#        'NESTLEIND', 'ONGC', 'POWERGRID', 'RELIANCE', 'SBILIFE', 'SBIN',
#        'SUNPHARMA', 'TCS', 'TATAGLOBAL', 'TATACONSUM', 'TATAMOTORS',
#        'TATASTEEL', 'TECHM', 'TITAN', 'UPL', 'ULTRACEMCO', 'WIPRO'],
#       dtype=object)

# %%
df1
# Out:
#             Date    Symbol Series  Prev Close    Open    High     Low    Last  \
# 0     2018-12-12  ADANIENT     EQ      151.90  152.80  157.00  151.05  156.00
# 1     2018-12-13  ADANIENT     EQ      156.10  156.00  158.60  154.00  154.15
# 2     2018-12-14  ADANIENT     EQ      156.00  156.00  157.90  154.10  157.00
# 3     2018-12-17  ADANIENT     EQ      157.10  157.10  158.90  156.35  158.00
# 4     2018-12-18  ADANIENT     EQ      157.95  157.70  159.75  156.20  158.10
# ...          ...       ...    ...         ...     ...     ...     ...     ...
# 47611 2022-12-06     WIPRO     EQ      412.35  410.50  412.60  407.80  410.95
# 47612 2022-12-07     WIPRO     EQ      411.35  409.00  409.50  405.30  405.50
# 47613 2022-12-08     WIPRO     EQ      406.30  407.25  408.00  403.30  403.85
# 47614 2022-12-09     WIPRO     EQ      403.70  406.00  406.00  391.25  394.15
# 47615 2022-12-12     WIPRO     EQ      394.05  392.90  397.50  388.00  397.15
#
# ...

# %%
df.corr()
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.999378  0.999276  0.999272  0.999157
# Open                  0.999378  1.000000  0.999851  0.999880  0.999750
# High                  0.999276  0.999851  1.000000  0.999806  0.999886
# Low                   0.999272  0.999880  0.999806  1.000000  0.999879
# Last                  0.999157  0.999750  0.999886  0.999879  1.000000
# Close                 0.999161  0.999753  0.999890  0.999884  0.999995
# VWAP                  0.999278  0.999869  0.999941  0.999939  0.999957
# Volume               -0.260102 -0.260286 -0.259736 -0.260635 -0.260146
# Turnover             -0.045038 -0.045453 -0.043384 -0.046501 -0.044610
# Trades               -0.199407 -0.200326 -0.198558 -0.201717 -0.199990
# Deliverable Volume   -0.263865 -0.264095 -0.263801 -0.264365 -0.264088
# %Deliverble          -0.012327 -0.012535 -0.014540 -0.011658 -0.013399
#
# ...

# %%
# take only one company wipro , take only Date,Close
Wipro = df[df["Symbol"] == "WIPRO"][["Date","Close"]].reset_index().drop("index",axis=1)
Wipro.dtypes
# Out:
# Date     datetime64[ns]
# Close           float64
# dtype: object

# %%
Wipro["Year"] = Wipro["Date"].dt.year

# %%
Wipro["Month"] = Wipro["Date"].dt.month
Wipro["Day"] = Wipro["Date"].dt.day

# %%
df1 = df1.set_index("Date",drop = True)

# %%
df1[df1["Symbol"]=="WIPRO"]["Open"].plot()
plt.show()

# %%
# name_of_stock = str(input())
# start_date = str(input())
# end_date = str(input())
# start_date = pd.to_datetime(start_date)
# end_date = pd.to_datetime(end_date)

# %%
Wipro = Wipro.drop("Date",axis=1)

# %%
# checking outlier
sns.boxplot(Wipro["Close"])
plt.show()
# Out:
# C:\Users\NOOMAN KHAN\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
X = Wipro.drop("Close",axis=1)
Y = Wipro[["Close"]].values

# %%
# scale the data
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X = sc.fit_transform(X)

# %%
# split independent feature
X_train = X[:int(len(X)*0.75)]
X_test = X[int(len(X)*0.75):]

# %%
len(X_train),len(X_test)
# Out:
# (744, 248)

# %%
# split dependent feature
Y_train = Y[:int(len(Y)*0.75)]
Y_test = Y[int(len(Y)*0.75):]

# %%
len(Y_train),len(Y_test)
# Out:
# (744, 248)

# %%
# model building
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = reg.predict(X_test)

# %%
# r2_score
from sklearn import metrics
metrics.r2_score(Y_pred,Y_test)
# Out:
# -22.439491684551882

# %% [markdown]
# ### r2_score in negative that's not possible means linear regression not work for this model

# %%
# mean_squared_error
from sklearn import metrics
metrics.mean_squared_error(Y_pred,Y_test)
# Out:
# 31571.518797773944

# %%
Y_test.ravel()
# Out:
# array([646.9 , 636.4 , 644.3 , 670.8 , 665.95, 690.8 , 685.65, 694.55,
#        698.45, 699.6 , 705.45, 703.7 , 714.1 , 715.35, 718.7 , 721.5 ,
#        713.5 , 705.75, 711.5 , 693.5 , 694.15, 691.35, 649.75, 639.8 ,
#        646.65, 633.3 , 621.15, 615.2 , 605.05, 572.75, 562.7 , 544.75,
#        552.15, 572.6 , 576.65, 588.  , 578.25, 571.75, 557.  , 560.25,
#        568.95, 573.65, 561.45, 541.7 , 563.35, 563.9 , 564.9 , 562.45,
#        570.8 , 564.15, 567.1 , 537.15, 555.25, 555.8 , 555.2 , 569.55,
#        575.3 , 571.85, 587.45, 585.5 , 588.25, 586.2 , 598.15, 587.7 ,
#        598.25, 601.2 , 600.  , 610.05, 611.2 , 610.55, 603.35, 600.2 ,
#        602.5 , 600.8 , 591.9 , 601.8 , 605.6 , 599.15, 593.55, 580.85,
#        583.65, 571.1 , 558.7 , 559.2 , 538.6 , 530.45, 536.5 , 539.2 ,
#        537.7 , 529.35, 529.25, 518.95, 522.55, 508.8 , 495.  , 491.75,
#        501.15, 485.1 , 483.15, 477.65, 471.9 , 473.8 , 468.65, 468.  ,
# ...

# %%
plt.plot(Y_test.ravel())
plt.plot(Y_pred.ravel())
plt.show()

# %% [markdown]
# You can see graph both predicted and actual totally different

# %%
# for i in df["Symbol"].unique().tolist():
#     Y = df[df["Symbol"]==i][["Close"]]
# Y

# %%
name_of_stock = input("Enter Name Of Stock")
number_of_share = int(input("Number Of Share"))
Y = df[df["Symbol"]==name_of_stock][["Close"]]
start_date = input("Start Date")
end_date = input("End Date")
start_date = pd.to_datetime(start_date)
end_date = pd.to_datetime(end_date)


from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
Y=scaler.fit_transform(np.array(Y).reshape(-1,1))



training_size=int(len(Y)*0.65)
test_size=len(Y)-training_size
train_data,test_data=Y[0:training_size,:],Y[training_size:len(Y),:1]


import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return numpy.array(dataX), numpy.array(dataY)


time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)


X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

### Create the Stacked LSTM model
pip install tensorflow==1.2.0 --ignore-installed
import tensorflow as tfl
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)




last_date = pd.to_datetime("2022-12-12")
lst_output_1=[]
lst_output_2=[]

diff_1 = start_date-last_date
diff_2 = end_date-last_date
if int(diff_1.days)>0:
    n_steps=100
    x_input=test_data[len(test_data)-n_steps:].reshape(1,-1)
    temp_input=list(x_input)
    temp_input=temp_input[0].tolist()
    i=0
    while(i<int(diff_1.days)):
        if(len(temp_input)>100):
            #print(temp_input)
            x_input=np.array(temp_input[1:])
#                 print("{} day input {}".format(i,x_input))
            x_input=x_input.reshape(1,-1)
            x_input = x_input.reshape((1, n_steps, 1))
            #print(x_input)
            yhat = model.predict(x_input, verbose=0)
#                 print("{} day output {}".format(i,yhat))
            temp_input.extend(yhat[0].tolist())
            temp_input=temp_input[1:]
            #print(temp_input)
            lst_output_1.extend(yhat.tolist())
            i=i+1
        else:
            x_input = x_input.reshape((1, n_steps,1))
            yhat = model.predict(x_input, verbose=0)
#                 print(yhat[0])
            temp_input.extend(yhat[0].tolist())
#                 print(len(temp_input))
            lst_output_1.extend(yhat.tolist())
            i=i+1


        
if int(diff_2.days)>0:
    n_steps=100
    x_input=test_data[len(test_data)-n_steps:].reshape(1,-1)
    temp_input=list(x_input)
    temp_input=temp_input[0].tolist()
    i=0
    while(i<int(diff_2.days)):
        if(len(temp_input)>100):
            #print(temp_input)
            x_input=np.array(temp_input[1:])
#                 print("{} day input {}".format(i,x_input))
            x_input=x_input.reshape(1,-1)
            x_input = x_input.reshape((1, n_steps, 1))
            #print(x_input)
            yhat = model.predict(x_input, verbose=0)
#                 print("{} day output {}".format(i,yhat))
            temp_input.extend(yhat[0].tolist())
            temp_input=temp_input[1:]
            #print(temp_input)
            lst_output_2.extend(yhat.tolist())
            i=i+1
        else:
            x_input = x_input.reshape((1, n_steps,1))
            yhat = model.predict(x_input, verbose=0)
#                 print(yhat[0])
            temp_input.extend(yhat[0].tolist())
#                 print(len(temp_input))
            lst_output_2.extend(yhat.tolist())
            i=i+1
        
invests = scaler.inverse_transform(lst_output_1)[-1]
returns = scaler.inverse_transform(lst_output_2)[-1]
Final_Amount = ((returns-invests)*number_of_share)

if Final_Amount>0:
    print("Profit: " ,Final_Amount)
else:
    print("Loss: " ,Final_Amount)
# Out:
#   Input In [238]
#     pip install tensorflow==1.2.0 --ignore-installed
#         ^
# SyntaxError: invalid syntax

# %%
# invests-returns*10

# %%
# returns

# %%
# pd.to_datetime("2023-01-05")-pd.to_datetime("2022-12-05")

# %% [markdown]
# #### LSTM MODEL

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
Y=scaler.fit_transform(np.array(Y).reshape(-1,1))

# %%
# split test data train data
training_size=int(len(Y)*0.65)
test_size=len(Y)-training_size
train_data,test_data=Y[0:training_size,:],Y[training_size:len(Y),:1]

# %%
# these are functoin which is used in split train,test,split
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
X_train.shape
# Out:
# (543, 100)

# %%
X_train.shape
# Out:
# (543, 100)

# %%
y_train.shape
# Out:
# (543,)

# %%
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %%
pip install tensorflow==1.2.0 --ignore-installed
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement tensorflow==1.2.0 (from versions: 2.5.0, 2.5.1, 2.5.2, 2.5.3, 2.6.0rc0, 2.6.0rc1, 2.6.0rc2, 2.6.0, 2.6.1, 2.6.2, 2.6.3, 2.6.4, 2.6.5, 2.7.0rc0, 2.7.0rc1, 2.7.0, 2.7.1, 2.7.2, 2.7.3, 2.7.4, 2.8.0rc0, 2.8.0rc1, 2.8.0, 2.8.1, 2.8.2, 2.8.3, 2.8.4, 2.9.0rc0, 2.9.0rc1, 2.9.0rc2, 2.9.0, 2.9.1, 2.9.2, 2.9.3, 2.10.0rc0, 2.10.0rc1, 2.10.0rc2, 2.10.0rc3, 2.10.0, 2.10.1, 2.11.0rc0, 2.11.0rc1, 2.11.0rc2, 2.11.0)
# ERROR: No matching distribution found for tensorflow==1.2.0

# %%
### Create the Stacked LSTM model
import tensorflow as tfl
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_3 (LSTM)               (None, 100, 50)           10400
#
#  lstm_4 (LSTM)               (None, 100, 50)           20200
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_3 (LSTM)               (None, 100, 50)           10400
#
#  lstm_4 (LSTM)               (None, 100, 50)           20200
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dense_1 (Dense)             (None, 1)                 51
#
# ...
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 4s 423ms/step - loss: 0.0109 - val_loss: 0.0342
# Epoch 2/100
# 9/9 [==============================] - 2s 197ms/step - loss: 0.0060 - val_loss: 0.0167
# Epoch 3/100
# 9/9 [==============================] - 2s 185ms/step - loss: 0.0025 - val_loss: 0.0037
# Epoch 4/100
# 9/9 [==============================] - 2s 183ms/step - loss: 0.0016 - val_loss: 0.0148
# Epoch 5/100
# 9/9 [==============================] - 2s 182ms/step - loss: 0.0015 - val_loss: 0.0073
# Epoch 6/100
# 9/9 [==============================] - 2s 187ms/step - loss: 0.0014 - val_loss: 0.0038
# Epoch 7/100
# 9/9 [==============================] - 2s 192ms/step - loss: 0.0013 - val_loss: 0.0060
# Epoch 8/100
# 9/9 [==============================] - 2s 236ms/step - loss: 0.0012 - val_loss: 0.0074
# Epoch 9/100
# 9/9 [==============================] - 2s 211ms/step - loss: 0.0011 - val_loss: 0.0050
# Epoch 10/100
# ...

# %%
# Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
# Out:
# ...
# 8/8 [==============================] - 0s 23ms/step

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)
test_predict
# Out:
# array([[649.0035 ],
#        [650.82916],
#        [651.257  ],
#        [651.2102 ],
#        [654.089  ],
#        [658.76324],
#        [666.9324 ],
#        [676.1378 ],
#        [685.4285 ],
#        [693.67523],
#        [699.86554],
#        [704.1662 ],
#        [706.21045],
#        [707.51276],
#        [708.4073 ],
#        [709.28625],
#        [710.35144],
#        [710.3354 ],
#        [708.3097 ],
#        [705.6873 ],
#        [700.9968 ],
#        [695.4329 ],
#        [689.9323 ],
#        [680.4122 ],
#        [667.6392 ],
#        [655.31616],
#        [644.203  ],
#        [634.36676],
#        [626.19196],
#        [619.3109 ],
#        [610.7333 ],
#        [600.4728 ],
#        [588.40424],
#        [577.31647],
#        [570.9693 ],
#        [570.1744 ],
#        [575.11115],
#        [582.8417 ],
#        [590.4289 ],
#        [594.6939 ],
#        [595.5714 ],
#        [594.68286],
#        [593.40247],
#        [590.8659 ],
#        [585.2314 ],
# ...

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 333.381134563564

# %%
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 510.2154035483609

# %%
### Plotting 
# shift train predictions for plotting
look_back=100
trainPredictPlot = numpy.empty_like(Y)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(Y)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(Y)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(Y))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()

# %%
len(test_data)
# Out:
# 348

# %%
x_input=test_data[318:].reshape(1,-1)
x_input.shape
# Out:
# (1, 30)

# %%
x_input=test_data[248:].reshape(1,-1)
temp_input=list(x_input)
temp_input=temp_input[0].tolist()

# %%
temp_input
# Out:
# [0.43351515693463294,
#  0.43512474291335057,
#  0.44666010909416076,
#  0.4500581239381204,
#  0.4444245730126084,
#  0.4514888670303139,
#  0.4343199499239917,
#  0.43691317177859246,
#  0.45363498166860416,
#  0.4674058839309666,
#  0.4768845569167486,
#  0.4779576142358938,
#  0.48287579361530897,
#  0.48850934454082084,
#  0.49655727443440933,
#  0.48913529464365557,
#  0.4789412501117768,
#  0.49378520969328443,
#  0.48958240185996604,
#  0.49137083072520793,
#  0.5020119824733971,
#  0.4877045515514621,
#  0.4830546365018331,
#  0.4607886971295716,
#  0.4547974604310113,
#  0.4539032459983904,
#  0.45220423857641057,
#  0.4558705177501564,
#  0.43279978538853614,
#  0.4492533309487615,
#  0.4437092014665116,
#  0.4387910220870964,
#  0.43485647858356435,
#  0.4329786282750603,
#  0.43834391487078594,
#  0.4479120092998301,
#  0.45569167486363227,
#  0.4643655548600554,
#  0.46552803362246264,
#  0.4541715103281767,
#  0.45193597424662435,
#  0.427971027452383,
# ...

# %%
from numpy import array

lst_output=[]
n_steps=100
i=0
while(i<30):
    
    if(len(temp_input)>100):
        #print(temp_input)
        x_input=np.array(temp_input[1:])
        print("{} day input {}".format(i,x_input))
        x_input=x_input.reshape(1,-1)
        x_input = x_input.reshape((1, n_steps, 1))
        #print(x_input)
        yhat = model.predict(x_input, verbose=0)
        print("{} day output {}".format(i,yhat))
        temp_input.extend(yhat[0].tolist())
        temp_input=temp_input[1:]
        #print(temp_input)
        lst_output.extend(yhat.tolist())
        i=i+1
    else:
        x_input = x_input.reshape((1, n_steps,1))
        yhat = model.predict(x_input, verbose=0)
        print(yhat[0])
        temp_input.extend(yhat[0].tolist())
        print(len(temp_input))
        lst_output.extend(yhat.tolist())
        i=i+1
    

print(lst_output)
# Out:
# [0.4509616]
# 101
# 1 day input [0.43512474 0.44666011 0.45005812 0.44442457 0.45148887 0.43431995
#  0.43691317 0.45363498 0.46740588 0.47688456 0.47795761 0.48287579
#  0.48850934 0.49655727 0.48913529 0.47894125 0.49378521 0.4895824
#  0.49137083 0.50201198 0.48770455 0.48305464 0.4607887  0.45479746
#  0.45390325 0.45220424 0.45587052 0.43279979 0.44925333 0.4437092
#  0.43879102 0.43485648 0.43297863 0.43834391 0.44791201 0.45569167
#  0.46436555 0.46552803 0.45417151 0.45193597 0.42797103 0.42850756
#  0.43378342 0.42636144 0.42135384 0.4149155  0.41572029 0.42215863
#  0.42153268 0.41214343 0.41473665 0.41518376 0.43485648 0.44317267
#  0.43950639 0.44522937 0.43288921 0.43923813 0.38764196 0.38442278
#  0.38048824 0.38799964 0.38576411 0.39193419 0.39381204 0.39765716
#  0.39756774 0.39399088 0.39506394 0.40096575 0.41142806 0.41420013
#  0.40445319 0.40811947 0.40981847 0.40883484 0.40516856 0.42448359
#  0.41885004 0.4199231  0.42189037 0.41920773 0.41402128 0.40472145
# ...

# %%
day_new=np.arange(1,30)
day_pred=np.arange(30,60)

# %%
len(Y)
# Out:
# 992

# %%
plt.plot(day_new,scaler.inverse_transform(Y[963:]))
plt.plot(day_pred,scaler.inverse_transform(lst_output))
plt.show()

# %%
df3=Y.tolist()
df3.extend(lst_output)
plt.plot(scaler.inverse_transform(df3))
plt.show()

# %%
def predict(Date_1):
    
    last_date = pd.to_datetime("2022-12-12") 
    Date = pd.to_datetime(Date_1)
    lst_output=[]
    diff = Date-last_date
    if int(diff.days)>0:
        n_steps=100
        x_input=test_data[len(test_data)-n_steps:].reshape(1,-1)
        temp_input=list(x_input)
        temp_input=temp_input[0].tolist()
        i=0
        while(i<int(diff.days)):
            if(len(temp_input)>100):
                #print(temp_input)
                x_input=np.array(temp_input[1:])
#                 print("{} day input {}".format(i,x_input))
                x_input=x_input.reshape(1,-1)
                x_input = x_input.reshape((1, n_steps, 1))
                #print(x_input)
                yhat = model.predict(x_input, verbose=0)
#                 print("{} day output {}".format(i,yhat))
                temp_input.extend(yhat[0].tolist())
                temp_input=temp_input[1:]
                #print(temp_input)
                lst_output.extend(yhat.tolist())
                i=i+1
            else:
                x_input = x_input.reshape((1, n_steps,1))
                yhat = model.predict(x_input, verbose=0)
#                 print(yhat[0])
                temp_input.extend(yhat[0].tolist())
#                 print(len(temp_input))
                lst_output.extend(yhat.tolist())
                i=i+1


    return scaler.inverse_transform(lst_output)[-1]

# %%
predict("2023-04-30")
# Out:
# array([680.62168537])

# %%
# def predict(Date_1):
#     last_date = pd.to_datetime("2022-12-12") 
#     Date = pd.to_datetime(Date_1)
#     lst_output=[]
#     diff = Date-last_date
#     if int(diff.days)>0:
        
#         return int(diff.days)

# %%
# predict("2022-12-18")

# %%
# pd.to_datetime("22-05-05")

# %%
# Invest = "2022-12-12"
# I_Date = pd.to_datetime(Invest)
# Widhrawl = "2022-12-15"
# W_Date = pd.to_datetime(Widhrawl)
# dif = I_Date-W_Date
# dif.days

# %%
# df["Date"].max()

# %%
def Stock_Model(Y):
    from sklearn.preprocessing import MinMaxScaler
    scaler=MinMaxScaler(feature_range=(0,1))
    Y=scaler.fit_transform(np.array(Y).reshape(-1,1))



    training_size=int(len(Y)*0.65)
    test_size=len(Y)-training_size
    train_data,test_data=Y[0:training_size,:],Y[training_size:len(Y),:1]


    import numpy
    # convert an array of values into a dataset matrix
    def create_dataset(dataset, time_step):
        dataX, dataY = [], []
        for i in range(len(dataset)-time_step-1):
            a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
            dataX.append(a)
            dataY.append(dataset[i + time_step, 0])
        return numpy.array(dataX), numpy.array(dataY)


    time_step = 100
    X_train, y_train = create_dataset(train_data, time_step)
    X_test, ytest = create_dataset(test_data, time_step)


    X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
    X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

    ### Create the Stacked LSTM model
    import tensorflow as tfl
    from tensorflow.keras.models import Sequential
    from tensorflow.keras.layers import Dense
    from tensorflow.keras.layers import LSTM

    model=Sequential()
    model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
    model.add(LSTM(50,return_sequences=True))
    model.add(LSTM(50))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error',optimizer='adam')
    model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=64,verbose=1)
    return model

# %%
ADANIENT_MODEL = Stock_Model(Y)
# Out:
# Epoch 1/100
# 9/9 [==============================] - 11s 390ms/step - loss: 0.0457 - val_loss: 0.0123
# Epoch 2/100
# 9/9 [==============================] - 2s 181ms/step - loss: 0.0075 - val_loss: 0.0157
# Epoch 3/100
# 9/9 [==============================] - 2s 184ms/step - loss: 0.0033 - val_loss: 0.0054
# Epoch 4/100
# 9/9 [==============================] - 2s 178ms/step - loss: 0.0016 - val_loss: 0.0162
# Epoch 5/100
# 9/9 [==============================] - 2s 176ms/step - loss: 0.0016 - val_loss: 0.0041
# Epoch 6/100
# 9/9 [==============================] - 2s 177ms/step - loss: 0.0013 - val_loss: 0.0036
# Epoch 7/100
# 9/9 [==============================] - 2s 176ms/step - loss: 0.0012 - val_loss: 0.0053
# Epoch 8/100
# 9/9 [==============================] - 2s 195ms/step - loss: 0.0011 - val_loss: 0.0049
# Epoch 9/100
# 9/9 [==============================] - 2s 188ms/step - loss: 0.0011 - val_loss: 0.0056
# Epoch 10/100
# ...

# %%
Y
# Out:
# array([[0.29991952],
#        [0.31530001],
#        [0.30537423],
#        [0.31699902],
#        [0.30886167],
#        [0.31896629],
#        [0.30564249],
#        [0.28570151],
#        [0.29392828],
#        [0.29294465],
#        [0.29526961],
#        [0.29991952],
#        [0.30135026],
#        [0.29383886],
#        [0.29187159],
#        [0.29178217],
#        [0.28990432],
#        [0.28954663],
#        [0.29187159],
#        [0.29804167],
#        [0.29222928],
#        [0.29750514],
#        [0.26862202],
#        [0.29947241],
#        [0.31154431],
#        [0.30948762],
#        [0.32871323],
#        [0.31377984],
#        [0.32933918],
#        [0.33837074],
#        [0.33872843],
#        [0.34176876],
#        [0.34480909],
#        [0.35240991],
#        [0.35929536],
#        [0.36993651],
#        [0.37413932],
#        [0.37360279],
#        [0.36859519],
#        [0.3753018 ],
#        [0.3778056 ],
#        [0.37619601],
#        [0.37682196],
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
Y=scaler.fit_transform(np.array(Y).reshape(-1,1))

training_size=int(len(Y)*0.65)
test_size=len(Y)-training_size
train_data,test_data=Y[0:training_size,:],Y[training_size:len(Y),:1]

# reshape into X=t,t+1,t+2,t+3 and Y=t+4

# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3-----99   100 
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)
    
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

train_predict=ADANIENT_MODEL.predict(X_train)
test_predict=ADANIENT_MODEL.predict(X_test)
test_predict
# Out:
# ...
# 8/8 [==============================] - 0s 53ms/step
# array([[0.8602266 ],
#        [0.8644418 ],
#        [0.8664896 ],
#        [0.8672041 ],
#        [0.8708265 ],
#        [0.876796  ],
#        [0.8876181 ],
#        [0.90099716],
#        [0.91569614],
#        [0.92998636],
#        [0.9420064 ],
#        [0.951178  ],
#        [0.9565053 ],
#        [0.95936275],
#        [0.9602868 ],
#        [0.9600476 ],
#        [0.9593193 ],
#        [0.9570279 ],
#        [0.95211303],
#        [0.9460831 ],
#        [0.9373646 ],
#        [0.9271791 ],
#        [0.91680247],
#        [0.9015997 ],
#        [0.8817474 ],
#        [0.8614383 ],
#        [0.8422299 ],
#        [0.8248839 ],
#        [0.8104157 ],
#        [0.7987775 ],
#        [0.7862635 ],
#        [0.77218264],
#        [0.75572103],
#        [0.7399756 ],
#        [0.7300904 ],
#        [0.72804743],
#        [0.7349095 ],
#        [0.74746364],
#        [0.7617218 ],
#        [0.7727448 ],
#        [0.77906096],
# ...

# %%
def predict_1(Date_1):
    
    last_date = pd.to_datetime("2022-12-12") 
    Date = pd.to_datetime(Date_1)
    lst_output=[]
    diff = Date-last_date
    if int(diff.days)>0:
        n_steps=100
        x_input=test_data[len(test_data)-n_steps:].reshape(1,-1)
        temp_input=list(x_input)
        temp_input=temp_input[0].tolist()
        i=0
        while(i<int(diff.days)):
            if(len(temp_input)>100):
                #print(temp_input)
                x_input=np.array(temp_input[1:])
#                 print("{} day input {}".format(i,x_input))
                x_input=x_input.reshape(1,-1)
                x_input = x_input.reshape((1, n_steps, 1))
                #print(x_input)
                yhat = ADANIENT_MODEL.predict(x_input, verbose=0)
#                 print("{} day output {}".format(i,yhat))
                temp_input.extend(yhat[0].tolist())
                temp_input=temp_input[1:]
                #print(temp_input)
                lst_output.extend(yhat.tolist())
                i=i+1
            else:
                x_input = x_input.reshape((1, n_steps,1))
                yhat = ADANIENT_MODEL.predict(x_input, verbose=0)
#                 print(yhat[0])
                temp_input.extend(yhat[0].tolist())
#                 print(len(temp_input))
                lst_output.extend(yhat.tolist())
                i=i+1


    return scaler.inverse_transform(lst_output)[-1]

# %%
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
look_back=100
trainPredictPlot = numpy.empty_like(Y)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
# shift test predictions for plotting
testPredictPlot = numpy.empty_like(Y)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(Y)-1, :] = test_predict
# plot baseline and predictions
plt.plot(scaler.inverse_transform(Y))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
